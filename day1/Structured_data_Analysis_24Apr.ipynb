# %%
import pandas as pd

# %%
# location: https://mitu.co.in/dataset

# download all the files starting from student*
# put in the same folder as jupyter notebook

# %%
pwd
# Out:
# '/home/aditya/GUEST_LECTURES/MIT_WPU'

# %%
from google.colab import files
files.upload()

# %%
df = pd.read_csv('student.csv')

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.shape
# Out:
# (10, 5)

# %%
df.dtypes
# Out:
# roll       int64
# name      object
# class     object
# marks    float64
# age        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
df.T
# Out:
#            0      1       2        3      4       5      6      7      8  \
# roll       1      2       3        4      5       6      7      8      9
# name    anil   amit  aniket  ajinkya   asha  ayesha   amar  amita   amol
# class     TE     TE      BE       TE     TE      BE     BE     BE     TE
# marks  56.77  59.77   76.88    69.66  63.28   49.55  65.34  68.33  56.75
# age       22     21      19       20     20      20     19     23     20
#
#            9
# roll      10
# name   anmol
# class     BE
# marks  78.66
# age       21

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.head()
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
df.head(3)
# Out:
#    roll    name class  marks  age
# 0     1    anil    TE  56.77   22
# 1     2    amit    TE  59.77   21
# 2     3  aniket    BE  76.88   19

# %%
df.tail()
# Out:
#    roll    name class  marks  age
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21

# %%
df = pd.read_csv('student1.csv')
df
# Out:
#     1     anil  TE  56.77  22
# 0   2     amit  TE  59.77  21
# 1   3   aniket  BE  76.88  19
# 2   4  ajinkya  TE  69.66  20
# 3   5     asha  TE  63.28  20
# 4   6   ayesha  BE  49.55  20
# 5   7     amar  BE  65.34  19
# 6   8    amita  BE  68.33  23
# 7   9     amol  TE  56.75  20
# 8  10    anmol  BE  78.66  21

# %%
header = ['A', 'B', 'C', 'D', 'E']

# %%
df = pd.read_csv('student1.csv', names = header)
df
# Out:
#     A        B   C      D   E
# 0   1     anil  TE  56.77  22
# 1   2     amit  TE  59.77  21
# 2   3   aniket  BE  76.88  19
# 3   4  ajinkya  TE  69.66  20
# 4   5     asha  TE  63.28  20
# 5   6   ayesha  BE  49.55  20
# 6   7     amar  BE  65.34  19
# 7   8    amita  BE  68.33  23
# 8   9     amol  TE  56.75  20
# 9  10    anmol  BE  78.66  21

# %%
df.iloc[2:5, 0:3]
# Out:
#    A        B   C
# 2  3   aniket  BE
# 3  4  ajinkya  TE
# 4  5     asha  TE

# %%
df.iloc[6:, :]
# Out:
#     A      B   C      D   E
# 6   7   amar  BE  65.34  19
# 7   8  amita  BE  68.33  23
# 8   9   amol  TE  56.75  20
# 9  10  anmol  BE  78.66  21

# %%
df.iloc[[4,5,7,9], [0,1,3]]
# Out:
#     A       B      D
# 4   5    asha  63.28
# 5   6  ayesha  49.55
# 7   8   amita  68.33
# 9  10   anmol  78.66

# %% [markdown]
# #### Label based slicing

# %%
df
# Out:
#     A        B   C      D   E
# 0   1     anil  TE  56.77  22
# 1   2     amit  TE  59.77  21
# 2   3   aniket  BE  76.88  19
# 3   4  ajinkya  TE  69.66  20
# 4   5     asha  TE  63.28  20
# 5   6   ayesha  BE  49.55  20
# 6   7     amar  BE  65.34  19
# 7   8    amita  BE  68.33  23
# 8   9     amol  TE  56.75  20
# 9  10    anmol  BE  78.66  21

# %%
df = pd.read_csv('student.csv')

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.loc[:, 'name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.loc[:, ['name', 'marks']]
# Out:
#       name  marks
# 0     anil  56.77
# 1     amit  59.77
# 2   aniket  76.88
# 3  ajinkya  69.66
# 4     asha  63.28
# 5   ayesha  49.55
# 6     amar  65.34
# 7    amita  68.33
# 8     amol  56.75
# 9    anmol  78.66

# %%
df['name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df[['name', 'marks']]
# Out:
#       name  marks
# 0     anil  56.77
# 1     amit  59.77
# 2   aniket  76.88
# 3  ajinkya  69.66
# 4     asha  63.28
# 5   ayesha  49.55
# 6     amar  65.34
# 7    amita  68.33
# 8     amol  56.75
# 9    anmol  78.66

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.drop(4)
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.drop([6,7])
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.drop('class', axis = 1)
# Out:
#    roll     name  marks  age
# 0     1     anil  56.77   22
# 1     2     amit  59.77   21
# 2     3   aniket  76.88   19
# 3     4  ajinkya  69.66   20
# 4     5     asha  63.28   20
# 5     6   ayesha  49.55   20
# 6     7     amar  65.34   19
# 7     8    amita  68.33   23
# 8     9     amol  56.75   20
# 9    10    anmol  78.66   21

# %%
help(df.drop)
# Out:
# Help on method drop in module pandas.core.frame:
#
# drop(labels: 'IndexLabel | None' = None, *, axis: 'Axis' = 0, index: 'IndexLabel | None' = None, columns: 'IndexLabel | None' = None, level: 'Level | None' = None, inplace: 'bool' = False, errors: 'IgnoreRaise' = 'raise') -> 'DataFrame | None' method of pandas.core.frame.DataFrame instance
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by directly specifying index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level. See the :ref:`user guide <advanced.shown_levels>`
#     for more information about the now unused levels.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop. A tuple will be used as a single
#         label and not treated as a list-like.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
# ...

# %% [markdown]
# ### Methods on columns

# %%
df['marks'].mean()
# Out:
# 64.499

# %%
df['marks'].max()
# Out:
# 78.66

# %%
df['marks'].median()
# Out:
# 64.31

# %%
df.mean(numeric_only= True)
# Out:
# roll      5.500
# marks    64.499
# age      20.500
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    10 non-null     int64
#  1   name    10 non-null     object
#  2   class   10 non-null     object
#  3   marks   10 non-null     float64
#  4   age     10 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 532.0+ bytes

# %%
df.describe()
# Out:
#            roll      marks        age
# count  10.00000  10.000000  10.000000
# mean    5.50000  64.499000  20.500000
# std     3.02765   9.207179   1.269296
# min     1.00000  49.550000  19.000000
# 25%     3.25000  57.520000  20.000000
# 50%     5.50000  64.310000  20.000000
# 75%     7.75000  69.327500  21.000000
# max    10.00000  78.660000  23.000000

# %% [markdown]
# #### modify or add new column

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df['marks'] = df['marks'] + 1

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  57.77   22
# 1     2     amit    TE  60.77   21
# 2     3   aniket    BE  77.88   19
# 3     4  ajinkya    TE  70.66   20
# 4     5     asha    TE  64.28   20
# 5     6   ayesha    BE  50.55   20
# 6     7     amar    BE  66.34   19
# 7     8    amita    BE  69.33   23
# 8     9     amol    TE  57.75   20
# 9    10    anmol    BE  79.66   21

# %%
df['cgpa'] = df['marks'] / 10 + 0.5

# %%
df
# Out:
#    roll     name class  marks  age   cgpa
# 0     1     anil    TE  57.77   22  6.277
# 1     2     amit    TE  60.77   21  6.577
# 2     3   aniket    BE  77.88   19  8.288
# 3     4  ajinkya    TE  70.66   20  7.566
# 4     5     asha    TE  64.28   20  6.928
# 5     6   ayesha    BE  50.55   20  5.555
# 6     7     amar    BE  66.34   19  7.134
# 7     8    amita    BE  69.33   23  7.433
# 8     9     amol    TE  57.75   20  6.275
# 9    10    anmol    BE  79.66   21  8.466

# %%
gender = ['m', 'm', 'm', 'm', 'f', 'f', 'm', 'f', 'm', 'm']

# %%
df['gender'] = gender

# %%
df
# Out:
#    roll     name class  marks  age   cgpa gender
# 0     1     anil    TE  57.77   22  6.277      m
# 1     2     amit    TE  60.77   21  6.577      m
# 2     3   aniket    BE  77.88   19  8.288      m
# 3     4  ajinkya    TE  70.66   20  7.566      m
# 4     5     asha    TE  64.28   20  6.928      f
# 5     6   ayesha    BE  50.55   20  5.555      f
# 6     7     amar    BE  66.34   19  7.134      m
# 7     8    amita    BE  69.33   23  7.433      f
# 8     9     amol    TE  57.75   20  6.275      m
# 9    10    anmol    BE  79.66   21  8.466      m

# %%
df.drop(['cgpa', 'gender'], axis = 1, inplace = True)

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  57.77   22
# 1     2     amit    TE  60.77   21
# 2     3   aniket    BE  77.88   19
# 3     4  ajinkya    TE  70.66   20
# 4     5     asha    TE  64.28   20
# 5     6   ayesha    BE  50.55   20
# 6     7     amar    BE  66.34   19
# 7     8    amita    BE  69.33   23
# 8     9     amol    TE  57.75   20
# 9    10    anmol    BE  79.66   21

# %% [markdown]
# ### merge and concat

# %%
ndf = pd.DataFrame({
    'roll': range(1,11),
    'cgpa': df['marks'] / 10 + 0.5,
    'gender': gender
})

# %%
ndf
# Out:
#    roll   cgpa gender
# 0     1  6.277      m
# 1     2  6.577      m
# 2     3  8.288      m
# 3     4  7.566      m
# 4     5  6.928      f
# 5     6  5.555      f
# 6     7  7.134      m
# 7     8  7.433      f
# 8     9  6.275      m
# 9    10  8.466      m

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  57.77   22
# 1     2     amit    TE  60.77   21
# 2     3   aniket    BE  77.88   19
# 3     4  ajinkya    TE  70.66   20
# 4     5     asha    TE  64.28   20
# 5     6   ayesha    BE  50.55   20
# 6     7     amar    BE  66.34   19
# 7     8    amita    BE  69.33   23
# 8     9     amol    TE  57.75   20
# 9    10    anmol    BE  79.66   21

# %%
x = pd.merge(ndf, df, on = 'roll')

# %%
x
# Out:
#    roll   cgpa gender     name class  marks  age
# 0     1  6.277      m     anil    TE  57.77   22
# 1     2  6.577      m     amit    TE  60.77   21
# 2     3  8.288      m   aniket    BE  77.88   19
# 3     4  7.566      m  ajinkya    TE  70.66   20
# 4     5  6.928      f     asha    TE  64.28   20
# 5     6  5.555      f   ayesha    BE  50.55   20
# 6     7  7.134      m     amar    BE  66.34   19
# 7     8  7.433      f    amita    BE  69.33   23
# 8     9  6.275      m     amol    TE  57.75   20
# 9    10  8.466      m    anmol    BE  79.66   21

# %%
df2 = pd.read_csv('student5.csv')
df2
# Out:
#    roll     name class  marks  age
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
pd.concat([df, df2])
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  57.77   22
# 1     2     amit    TE  60.77   21
# 2     3   aniket    BE  77.88   19
# 3     4  ajinkya    TE  70.66   20
# 4     5     asha    TE  64.28   20
# 5     6   ayesha    BE  50.55   20
# 6     7     amar    BE  66.34   19
# 7     8    amita    BE  69.33   23
# 8     9     amol    TE  57.75   20
# 9    10    anmol    BE  79.66   21
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %% [markdown]
# #### string operations on columns

# %%
df['name'].str.upper()
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       ASHA
# 5     AYESHA
# 6       AMAR
# 7      AMITA
# 8       AMOL
# 9      ANMOL
# Name: name, dtype: object

# %%
df['name'].str.title()
# Out:
# 0       Anil
# 1       Amit
# 2     Aniket
# 3    Ajinkya
# 4       Asha
# 5     Ayesha
# 6       Amar
# 7      Amita
# 8       Amol
# 9      Anmol
# Name: name, dtype: object

# %%
df['name'].str.startswith('am')
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# 9    False
# Name: name, dtype: bool

# %%
df['name'].str.endswith('l')
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8     True
# 9     True
# Name: name, dtype: bool

# %% [markdown]
# #### Boolean filtering

# %%
df[df['marks'] > 60]
# Out:
#    roll     name class  marks  age
# 1     2     amit    TE  60.77   21
# 2     3   aniket    BE  77.88   19
# 3     4  ajinkya    TE  70.66   20
# 4     5     asha    TE  64.28   20
# 6     7     amar    BE  66.34   19
# 7     8    amita    BE  69.33   23
# 9    10    anmol    BE  79.66   21

# %%
df[(df['marks'] > 60) & (df['age'] > 20)]
# Out:
#    roll   name class  marks  age
# 1     2   amit    TE  60.77   21
# 7     8  amita    BE  69.33   23
# 9    10  anmol    BE  79.66   21

# %%
p = df[(df['marks'] > 60) & (df['class'] == 'TE')]

# %%
p
# Out:
#    roll     name class  marks  age
# 1     2     amit    TE  60.77   21
# 3     4  ajinkya    TE  70.66   20
# 4     5     asha    TE  64.28   20

# %% [markdown]
# ### Export

# %%
x.to_csv('output.csv', index= False)

# %%
x.to_html('op.html', index= False)
